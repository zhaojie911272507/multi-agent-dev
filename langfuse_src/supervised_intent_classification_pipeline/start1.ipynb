# %%
import pathlib
import warnings
warnings.filterwarnings("ignore")

# print(pathlib.Path(__file__).absolute())

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Get keys for your project from the project settings page: https://cloud.langfuse.com
os.environ["LANGFUSE_PUBLIC_KEY"] = os.getenv("LANGFUSE_PUBLIC_KEY")
os.environ["LANGFUSE_SECRET_KEY"] = os.getenv("LANGFUSE_SECRET_KEY")
os.environ["LANGFUSE_HOST"] = os.getenv("LANGFUSE_HOST")  # 🇪🇺 EU region
# os.environ["LANGFUSE_HOST"] = "https://us.cloud.langfuse.com" # 🇺🇸 US region

# Your DeepSeek API key (get it from https://platform.deepseek.com/api_keys)
os.environ["DEEPSEEK_API_KEY"] = os.getenv("DEEPSEEK_API_KEY")  # Replace with your DeepSeek API key

# %%
# Select embedding model
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("/Users/zhaojie/project/langgraphtest0725/model_files/embeddingmodel/all-mpnet-base-v2")
print(embedding_model.encode("你好哇 先生"))
# Out:
# [ 3.13723013e-02 -8.15289654e-03 -1.15727317e-02  1.07067619e-02
#   1.39965797e-02 -1.22439405e-02 -6.50949702e-02  3.47239859e-02
#   1.05272690e-02  2.43837722e-02  1.06491968e-02 -3.52041498e-02
#   5.27302772e-02  2.41654310e-02 -4.65646461e-02 -6.45199642e-02
#   1.85884684e-02  2.73917112e-02  4.58659306e-02 -1.85253751e-02
#  -3.72554064e-02  1.06794676e-02  2.67252252e-02  1.60255320e-02
#   3.61067168e-02 -4.81615067e-02  1.39088342e-02 -2.20511984e-02
#   4.48988006e-03  1.80214681e-02  2.27014404e-02 -2.42200512e-02
#  -4.18279767e-02  1.75161322e-03  1.62636366e-06 -1.03442138e-02
#  -8.53871182e-03 -3.41529809e-02 -2.62655038e-02 -4.49964590e-02
#   2.41143182e-02 -2.32828129e-02 -2.06837878e-02  1.98148619e-02
#  -1.28621776e-02 -3.13797854e-02  1.86386090e-02  4.71481308e-03
#   2.22410802e-02  1.86205599e-02 -8.40432476e-04 -9.33283865e-02
#  -1.65852010e-02 -1.36640258e-02  3.13267298e-02  2.28635129e-02
#   1.56473671e-03 -3.86138111e-02 -6.64851665e-02  2.83993781e-02
#  -8.37120414e-03 -4.01876383e-02  2.80901175e-02 -2.57560723e-02
#  -2.78310291e-02  9.11103282e-03 -9.10281111e-03  8.81519634e-03
#   5.48511418e-03  9.42631215e-02 -1.87348593e-02  2.19302215e-02
#   3.62056978e-02  4.94792648e-02  3.41965221e-02 -7.76069164e-02
#  -1.28219789e-02 -1.97244622e-03  2.88219117e-02 -6.45518079e-02
#  -7.54477903e-02  2.00436451e-02  1.70828197e-02  4.03003916e-02
#   7.92520493e-03  3.61740291e-02 -3.40755060e-02 -8.16086715e-04
#   3.15162027e-03 -5.13159893e-02  2.60477904e-02  2.88386997e-02
#  -2.85127461e-02  1.07872346e-02 -4.96951072e-03  4.58764732e-02
#  -5.10673299e-02 -8.70648474e-02 -8.27519409e-03 -6.55070916e-02
#   1.46392977e-03 -1.54974293e-02 -1.68903824e-02 -5.03173433e-02
#  -4.40264195e-02  3.90954055e-02 -8.81671626e-03  1.96520425e-02
#  -1.07649257e-02 -7.34382123e-02  2.18567788e-04 -1.41553059e-02
#   2.28742408e-07 -9.87198669e-03 -3.76428030e-02 -2.16817092e-02
#   4.22177389e-02  4.56285402e-02 -3.90796252e-02 -1.79633182e-02
#  -2.35231295e-02 -1.10889897e-02  3.29462141e-02  1.22033440e-01
#   1.61770178e-04  3.74352634e-02 -1.26711568e-02 -1.03236951e-01
#   1.12658869e-02 -4.52016518e-02 -8.34301040e-02  3.77678983e-02
#   3.62675898e-02 -4.41531977e-03 -1.50895566e-02 -1.11389877e-02
#   2.77680773e-02  2.82897335e-02  4.58865333e-03  1.78204328e-02
#  -2.67301761e-02  1.55460611e-02  6.81720302e-02  2.38013198e-03
#  -1.48207722e-02 -3.56300138e-02 -5.72751462e-02  9.21738334e-03
#  -4.63066250e-02  7.71128014e-02  3.66192162e-02 -1.71623491e-02
#   8.44888762e-02 -1.88012782e-03  3.67047451e-02  1.66003946e-02
#   2.90535018e-02  6.11477196e-02  2.73654405e-02 -1.58078000e-02
#  -1.52120541e-03  4.46295505e-03  1.32119702e-02 -3.77582870e-02
#  -1.38686784e-02  9.24019516e-03 -1.59952212e-02  1.27853989e-03
#  -5.44414390e-03  3.29630412e-02 -2.84973830e-02  2.06205677e-02
#  -8.21450353e-03 -1.13606993e-02 -2.97151934e-02  1.76551100e-02
#   6.45216629e-02  5.70882112e-02 -9.32129659e-03  2.71446677e-03
#   9.76335991e-35  4.48236056e-03 -2.04366520e-02 -3.60474922e-03
#   6.98634014e-02 -2.96771526e-02 -4.54770103e-02  2.02311371e-02
#  -2.24039871e-02  1.52081028e-02  2.06799824e-02 -4.96815629e-02]

# %%
from langfuse import Langfuse
langfuse = Langfuse()
# Out:
# 2025-09-13 16:18:54,575 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:18:55,581 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:18:56,587 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:18:57,591 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:18:58,596 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:18:59,602 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs

# %%
sample_utterances = [
    "Hello again",
    "Can you do anything else?",
    "Could you recommend a good book?",
    "I'd like to watch a drama",
    "Please revert to the beginning"
]

# Create dummy traces
for utterance in sample_utterances:
    langfuse.update_current_trace(input={"message": utterance})
    # langfuse.trace
# Out:
# 2025-09-13 16:58:54,754 - langfuse - WARNING - Context error: No active span in current context. Operations that depend on an active span will be skipped. Ensure spans are created with start_as_current_span() or that you're operating within an active span context.
# 2025-09-13 16:58:54,755 - langfuse - WARNING - Context error: No active span in current context. Operations that depend on an active span will be skipped. Ensure spans are created with start_as_current_span() or that you're operating within an active span context.
# 2025-09-13 16:58:54,755 - langfuse - WARNING - Context error: No active span in current context. Operations that depend on an active span will be skipped. Ensure spans are created with start_as_current_span() or that you're operating within an active span context.
# 2025-09-13 16:58:54,756 - langfuse - WARNING - Context error: No active span in current context. Operations that depend on an active span will be skipped. Ensure spans are created with start_as_current_span() or that you're operating within an active span context.
# 2025-09-13 16:58:54,756 - langfuse - WARNING - Context error: No active span in current context. Operations that depend on an active span will be skipped. Ensure spans are created with start_as_current_span() or that you're operating within an active span context.
# 2025-09-13 16:58:55,226 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:58:56,230 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:58:57,236 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:58:58,238 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:58:59,244 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:59:00,251 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs

# %%
traces = langfuse.fetch_traces()
traces.data[0].dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 traces = langfuse.fetch_traces()
#       2 traces.data[0].dict()
#
# AttributeError: 'Langfuse' object has no attribute 'fetch_traces'
# 2025-09-13 16:16:14,612 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:15,615 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:16,621 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:17,625 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:18,631 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:19,635 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:20,641 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:21,647 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:22,652 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs

# %%
traces_list = []
for trace in traces.data:
    trace_info = [trace.id, trace.input["message"]]
    traces_list.append(trace_info)

import pandas as pd
traces_df = pd.DataFrame(traces_list, columns=["trace_id", "message"])
traces_df.head()
# Out:
# 2025-09-13 16:12:41,582 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 traces_list = []
# ----> 2 for trace in traces.data:
#       3     trace_info = [trace.id, trace.input["message"]]
#       4     traces_list.append(trace_info)
#
# NameError: name 'traces' is not defined
# 2025-09-13 16:12:42,593 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:43,597 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:44,604 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:45,610 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:46,616 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:47,620 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:48,622 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:49,625 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:50,631 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:51,635 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:52,641 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:53,648 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs

# %%
# 2. Build and train an intent classification model
import numpy as np
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from tqdm.notebook import tqdm

# %%
# Note: This is a very small dataset.
# More data will help make the model  more accurate and avoid overfitting.
sample_data = {
    "text": [
        # Greeting utterances
        "hi",
        "hello",
        "howdy",
        "hey there",
        "greetings",
        "Nice to see you",
        "Let's start",
        "begin",
        "good morning",
        "Good afternoon",
        # Menu utterances
        "I want to talk about something else",
        "options",
        "menu, please",
        "Could we chat about another subject",
        "I want to see the menu",
        "switch topics",
        "What else can you do",
        "discuss about something else",
        "Show me the menu",
        "Can we do something else",
        # Restart utterances
        "restart",
        "I'd like to do this again",
        "let me try again",
        "one more time",
        "Can I review that?",
        "check again",
        "redo",
        "again please",
        "that was great, let's start from the beginning",
        "go back to start",
    ],
    "intent": [
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "greeting",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "menu",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
        "restart",
    ]
}

# %%
import pandas as pd
df = pd.DataFrame(sample_data)
df.head()
# Out:
#         text    intent
# 0         hi  greeting
# 1      hello  greeting
# 2      howdy  greeting
# 3  hey there  greeting
# 4  greetings  greeting

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["text"],
    df["intent"],
    test_size=0.5,
    random_state=14
)

# %%
class Encoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.embedding_model = embedding_model

    def transform(self, X):
        return self.embedding_model.encode(list(X))

    def fit(self, X, y=None):
        return self

# %%
pipeline = Pipeline([
    ('encoder', Encoder()),
    ('clf', LogisticRegression()),
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('encoder', Encoder()), ('clf', LogisticRegression())])

# %%
y_pred = pipeline.predict(X_test)
y_pred
# Out:
# array(['greeting', 'menu', 'menu', 'greeting', 'restart', 'greeting',
#        'restart', 'menu', 'greeting', 'greeting', 'restart', 'greeting',
#        'menu', 'menu', 'menu'], dtype=object)

# %%
single_pred = pipeline.predict(["Please let's move on"])
single_pred
# Out:
# array(['menu'], dtype=object)

# %%
probas = pipeline.predict_proba(["Please let's move on"])
probas
# Out:
# array([[0.30275494, 0.39219674, 0.30504832]])

# %%
confidence_score = float(np.max(probas, axis=1)[0])
confidence_score
# Out:
# 0.39219674030845886

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     greeting       0.83      1.00      0.91         5
#         menu       0.67      1.00      0.80         4
#      restart       1.00      0.50      0.67         6
#
#     accuracy                           0.80        15
#    macro avg       0.83      0.83      0.79        15
# weighted avg       0.86      0.80      0.78        15

# %%
# Run predictions on traces
for index, row in traces_df.iterrows():
    result =  pipeline.predict([row["message"]])
    probas = pipeline.predict_proba([row["message"]])
    confidence_score = float(np.max(probas, axis=1)[0])

    traces_df.at[index, "label"] = "".join(result)
    traces_df.at[index, "confidence_score"] = confidence_score

traces_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Run predictions on traces
# ----> 2 for index, row in traces_df.iterrows():
#       3     result =  pipeline.predict([row["message"]])
#       4     probas = pipeline.predict_proba([row["message"]])
#
# NameError: name 'traces_df' is not defined
# 2025-09-13 16:12:54,653 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:55,659 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:56,665 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:57,672 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:58,677 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:12:59,682 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:00,687 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:01,692 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:02,693 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:03,699 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:04,705 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:05,710 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:06,715 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:13:07,721 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs

# %%
# Note: This will add to existing tags, not add duplicate tags.
for index, row in traces_df.iterrows():
    if row["confidence_score"] > 0.30:
        trace_id = row["trace_id"]
        label = row["label"]
        langfuse.trace(id=trace_id, tags = [label])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Note: This will add to existing tags, not add duplicate tags.
# ----> 2 for index, row in traces_df.iterrows():
#       3     if row["confidence_score"] > 0.30:
#       4         trace_id = row["trace_id"]
#
# NameError: name 'traces_df' is not defined
# 2025-09-13 16:14:47,184 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:48,185 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:49,189 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:50,195 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:51,201 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:52,207 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:53,213 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:54,219 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:55,222 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:56,228 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:57,233 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:58,239 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:14:59,243 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:00,250 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:01,252 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:02,259 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:03,265 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:04,271 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:05,277 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:06,283 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:07,288 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:08,291 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:09,297 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:10,304 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:11,310 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:12,314 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:13,320 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:14,325 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:15,329 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:16,336 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:17,341 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:18,347 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:19,353 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:20,360 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:21,364 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:22,366 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:23,371 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:24,377 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:25,383 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:26,389 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:27,395 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:28,400 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:29,405 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:30,410 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:31,412 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:32,419 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:33,421 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:34,426 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:35,429 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:36,435 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:37,438 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:38,444 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:39,447 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:40,453 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:41,458 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:42,464 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:43,469 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:44,474 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:45,479 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:46,485 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:47,487 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:48,490 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:49,494 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:50,496 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:51,498 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:52,504 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:53,510 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:54,517 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:55,522 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:56,528 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:57,534 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:58,538 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:15:59,541 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:00,547 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:01,552 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:02,558 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:03,563 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:04,564 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:05,569 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:06,576 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:07,581 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:08,585 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:09,588 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:10,590 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:11,596 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:12,599 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
# 2025-09-13 16:16:13,605 - langfuse - DEBUG - Queue: Media upload queue is empty, waiting for new jobs
